# %%
import os
import sys
sys.path.append(os.path.abspath('..'))
from models import OurSmallModel
from models import OurBigModel
import torch
import pytorch_lightning as pl
# Out:
# Total length of dataset: 3599
# Train size: 3239
# Validation size: 360
# Podfoldery (klasy): ['1', '2', '3', '4', '5', '6', '7', '8', '9']
# Rozkład etykiet: Counter({7: 424, 2: 423, 4: 413, 1: 410, 6: 409, 0: 397, 3: 387, 5: 373, 8: 363})
# Train size: 3239
# Validation size: 360

# %%
print(f"Cuda available: {torch.cuda.is_available()}")
# Out:
# Cuda available: True

# %%
torch.manual_seed(0)
model = OurBigModel()

trainer = pl.Trainer(max_epochs=20, accelerator='gpu', devices=1)
trainer.fit(model)
# Out:
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Users\jakub\PycharmProjects\sudoku\.venv\Lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# ...

# %%
model.plot_metrics()
# Out:
# === STATYSTYKI ModelCNN ===
# Końcowa accuracy: 0.9944
# Najlepsza accuracy: 0.9972
# Końcowy loss: 0.0197
# Liczba epok: 26

# %%
torch.save(model, "../notebooks/firstBigModel_test.pt")

# %%
# Out:
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 6
#       1 model = OurBigModel()
#       3 trainer = pl.Trainer(max_epochs=25, accelerator='gpu', devices=1)
# ----> 6 lr_finder = trainer.tuner.lr_find(model)
#       9 fig = lr_finder.plot(suggest=True)
#      10 fig.show()
#
# AttributeError: 'Trainer' object has no attribute 'tuner'
