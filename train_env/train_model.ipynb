# %%
import os
import sys
sys.path.append(os.path.abspath('..'))
from models import OurSmallModel
import torch
import pytorch_lightning as pl
# Out:
# Total length of dataset: 3599
# Train size: 3239
# Validation size: 360
# Podfoldery (klasy): ['1', '2', '3', '4', '5', '6', '7', '8', '9']
# Rozkład etykiet: Counter({7: 424, 2: 423, 4: 413, 1: 410, 6: 409, 0: 397, 3: 387, 5: 373, 8: 363})
# Train size: 3239
# Validation size: 360

# %%
print(f"Cuda available: {torch.cuda.is_available()}")
# Out:
# Cuda available: True

# %%
torch.manual_seed(0)
model = OurSmallModel(model="dupa")

trainer = pl.Trainer(max_epochs=20, accelerator='gpu', devices=1)
trainer.fit(model)
# Out:
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/przemekk/PycharmProjects/pl_sudoku/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type   | Params | Mode
# ------------------------------------------------
# ...

# %%
model.plot_metrics()
# Out:
# === STATYSTYKI Modelv1 ===
# Końcowa accuracy: 0.9528
# Najlepsza accuracy: 0.9722
# Końcowy loss: 0.1355
# Liczba epok: 21

# %%
torch.save(model, "first_test.pt")
