# %%
import sys
import os
import torch
import importlib
import process
importlib.reload(process)

sys.path.append(os.path.abspath(".."))

from helper_methods import get_best_mask, get_corners, get_squares, correct_squares, plot_images, perspective_transform
from process import process_sudoku_image
from models import OurSmallModel, val_tfms,OurBigModel

# %%
model_eval = torch.load("firstBigModel_test.pt", weights_only=False)

# %%
img = "../test_images/test_5.jpg"
process_sudoku_image(img, model_eval, val_tfms)
# Out:
# [ERROR] Predicted index 8 out of range for class list!
# [ERROR] Predicted index 8 out of range for class list!
# [ERROR] Predicted index 8 out of range for class list!
# [ERROR] Predicted index 8 out of range for class list!
# [ERROR] Predicted index 8 out of range for class list!
# Predykcje jako tensor PyTorch:
# tensor([[0, 5, 1, 2, 0, 0, 0, 0, 0],
#         [0, 3, 8, 0, 7, 0, 0, 4, 0],
#         [2, 0, 0, 5, 0, 0, 0, 0, 6],
#         [1, 2, 3, 6, 0, 0, 7, 0, 0],
#         [8, 7, 0, 3, 0, 1, 0, 5, 4],
#         [0, 0, 0, 0, 0, 8, 3, 6, 1],
#         [4, 0, 0, 0, 0, 2, 0, 1, 5],
#         [0, 1, 0, 8, 6, 0, 4, 3, 0],
#         [0, 6, 0, 0, 0, 7, 0, 2, 0]], dtype=torch.int32)
# array([[0, 5, 1, 2, 0, 0, 0, 0, 0],
#        [0, 3, 8, 0, 7, 0, 0, 4, 0],
#        [2, 0, 0, 5, 0, 0, 0, 0, 6],
#        [1, 2, 3, 6, 0, 0, 7, 0, 0],
#        [8, 7, 0, 3, 0, 1, 0, 5, 4],
#        [0, 0, 0, 0, 0, 8, 3, 6, 1],
#        [4, 0, 0, 0, 0, 2, 0, 1, 5],
#        [0, 1, 0, 8, 6, 0, 4, 3, 0],
#        [0, 6, 0, 0, 0, 7, 0, 2, 0]])
