# %%
import sys
import os
import torch
sys.path.append(os.path.abspath(".."))

from helper_methods import get_best_mask, get_corners, get_squares, correct_squares, plot_images, perspective_transform
from process import process_sudoku_image
from models import OurSmallModel, val_tfms
# Out:
# Total length of dataset: 3599
# Total length of train dataset: 3239
# Total length of valid dataset: 360

# %%
testing = torch.load("model.pt", weights_only=False)

# %%
img = "/home/przemekk/PycharmProjects/pl_sudoku/test_2.png"
process_sudoku_image(img, testing, val_tfms)
# Out:
# Predykcje jako tensor PyTorch:
# tensor([[5, 3, 0, 0, 7, 0, 0, 0, 0],
#         [6, 0, 0, 1, 9, 5, 0, 0, 0],
#         [0, 9, 8, 0, 0, 0, 0, 6, 0],
#         [8, 0, 0, 0, 6, 0, 0, 0, 3],
#         [4, 0, 0, 8, 0, 3, 0, 0, 1],
#         [7, 0, 0, 0, 3, 0, 0, 0, 6],
#         [0, 6, 0, 0, 0, 0, 2, 8, 0],
#         [0, 0, 0, 4, 1, 9, 0, 0, 5],
#         [0, 0, 0, 0, 8, 0, 0, 7, 9]], dtype=torch.int32)
# 0
